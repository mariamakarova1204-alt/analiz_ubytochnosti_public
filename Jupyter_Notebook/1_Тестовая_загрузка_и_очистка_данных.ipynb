# %%
import pandas as pd

# %%
#читаем наш файл
df = pd.read_csv(
    r'C:\Users\Maria\OneDrive\Desktop\Анализ_убыточности_типографии\Данные\CSV_из_excel_в_csv\1c_90_2024.csv',
    sep=';',
    encoding='utf-8'
)

df.head(10)
# Out:
#                                           Unnamed: 0  \
# 0                              Карточка счета: 90.01
# 1   : Виды деят. : Полиграфическая : Ставка НДС :...
# 2                                         за 2024 г.
# 3                                ООО "Капитал Принт"
# 4                                               Дата
# 5                                                NaN
# 6                                 Сальдо на 01.01.24
# 7                                           03.01.24
# 8                                           03.01.24
# 9                                           03.01.24
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           Документ
# 5                                                NaN
# ...

# %%
#выводим названия колонок
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']

# %%
#смотрим, как это выглядит
df.head(15)
# Out:
#                                            Unnamed: 0  \
# 0                               Карточка счета: 90.01
# 1    : Виды деят. : Полиграфическая : Ставка НДС :...
# 2                                          за 2024 г.
# 3                                 ООО "Капитал Принт"
# 4                                                Дата
# 5                                                 NaN
# 6                                  Сальдо на 01.01.24
# 7                                            03.01.24
# 8                                            03.01.24
# 9                                            03.01.24
# 10                                           04.01.24
# 11                                           04.01.24
# 12                                           04.01.24
# 13                                           04.01.24
# 14                                           04.01.24
#
#                                            Unnamed: 1  \
# ...

# %%
#смотрим, сколько колонок и строк
print(df.columns.tolist())
df.shape
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
# (1522, 9)

# %%
#оставляем только нужные колонки
df.iloc[:8]
# Out:
#                                           Unnamed: 0           Unnamed: 1  \
# 0                              Карточка счета: 90.01                  NaN
# 1   : Виды деят. : Полиграфическая : Ставка НДС :...                  NaN
# 2                                         за 2024 г.                  NaN
# 3                                ООО "Капитал Принт"                  NaN
# 4                                               Дата             Документ
# 5                                                NaN                  NaN
# 6                                 Сальдо на 01.01.24                  NaN
# 7                                           03.01.24  Накладная ШЖ1827905
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# ...

# %%
#берем первую строку как названия столбцов
df.columns = df.iloc[0]
#удаляем лишние строки
df = df[7:]
#сбрасываем индексы
df = df.reset_index(drop=True)
#смотрим, что получилось
df.head()
# Out:
# 0 Карточка счета: 90.01                                                NaN  \
# 0              03.01.24                                Накладная ШЖ1827905
# 1              03.01.24                                Накладная ЭЕ0138062
# 2              03.01.24  Акт вып. работ (реализ) с табл. частью 0000000...
# 3              04.01.24                                Накладная ШЖ1827906
# 4              04.01.24                                Накладная ЭЕ0138064
#
# 0                                                NaN   NaN NaN    NaN  \
# 0  Продажа (счет 90)/ Евроторг Учтена выручка\nЕв...  62.1      90.01
# 1  Продажа (счет 90)/ Корс Сити ООО Учтена выручк...  62.1      90.01
# 2  Акт вып.работ (реализ), табл, покупатель: ИСТ ...  62.1      90.01
# 3  Продажа (счет 90)/ Академическая книга Учтена ...  62.1      90.01
# 4  Продажа (счет 90)/ Авангард-торг Учтена выручк...  62.1      90.01
#
# 0       NaN NaN NaN
# 0    503,82
# 1    620,16
# 2     90,90
# 3  1 422,00
# 4     38,40

# %%
#смотрим, сколько колонок и строк
print(df.columns.tolist())
df.shape
# Out:
# ['Карточка счета: 90.01', nan, nan, nan, nan, nan, nan, nan, nan]
# (1515, 9)

# %%
#сбрасываем индексы
df = df.iloc[2:].reset_index(drop=True)
df.head()
# Out:
# 0 Карточка счета: 90.01                                                NaN  \
# 0              03.01.24  Акт вып. работ (реализ) с табл. частью 0000000...
# 1              04.01.24                                Накладная ШЖ1827906
# 2              04.01.24                                Накладная ЭЕ0138064
# 3              04.01.24                                Накладная ШЖ1827907
# 4              04.01.24                                Накладная ШЖ1827908
#
# 0                                                NaN   NaN NaN    NaN  \
# 0  Акт вып.работ (реализ), табл, покупатель: ИСТ ...  62.1      90.01
# 1  Продажа (счет 90)/ Академическая книга Учтена ...  62.1      90.01
# 2  Продажа (счет 90)/ Авангард-торг Учтена выручк...  62.1      90.01
# 3  Продажа (счет 90)/ Кинг тут ООО Учтена выручка...  62.1      90.01
# 4  Продажа (счет 90)/ Апулья ООО Учтена выручка\n...  62.1      90.01
#
# 0       NaN NaN NaN
# 0     90,90
# 1  1 422,00
# 2     38,40
# 3  1 426,32
# 4    201,26

# %%
#смотрим кол-во колонок и строк
df.shape
# Out:
# (1513, 9)

# %%
#смотрим параметры нашего DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Карточка счета: 90.01  1512 non-null   str
#  1   nan                    1510 non-null   str
#  2   nan                    1510 non-null   str
#  3   nan                    1510 non-null   str
#  4   nan                    1512 non-null   str
#  5   nan                    1510 non-null   str
#  6   nan                    1512 non-null   str
#  7   nan                    1510 non-null   str
#  8   nan                    1510 non-null   str
# dtypes: str(9)
# memory usage: 106.5 KB

# %%
#выводим номера колонок
for i, col in enumerate(df.columns):
    print(i, col)
# Out:
# 0 Карточка счета: 90.01
# 1 nan
# 2 nan
# 3 nan
# 4 nan
# 5 nan
# 6 nan
# 7 nan
# 8 nan

# %%
df.head()
# Out:
# 0 Карточка счета: 90.01                                                NaN  \
# 0              03.01.24  Акт вып. работ (реализ) с табл. частью 0000000...
# 1              04.01.24                                Накладная ШЖ1827906
# 2              04.01.24                                Накладная ЭЕ0138064
# 3              04.01.24                                Накладная ШЖ1827907
# 4              04.01.24                                Накладная ШЖ1827908
#
# 0                                                NaN   NaN NaN    NaN  \
# 0  Акт вып.работ (реализ), табл, покупатель: ИСТ ...  62.1      90.01
# 1  Продажа (счет 90)/ Академическая книга Учтена ...  62.1      90.01
# 2  Продажа (счет 90)/ Авангард-торг Учтена выручк...  62.1      90.01
# 3  Продажа (счет 90)/ Кинг тут ООО Учтена выручка...  62.1      90.01
# 4  Продажа (счет 90)/ Апулья ООО Учтена выручка\n...  62.1      90.01
#
# 0       NaN NaN NaN
# 0     90,90
# 1  1 422,00
# 2     38,40
# 3  1 426,32
# 4    201,26

# %%
#присваиваем названия нашим колонкам
df.columns = [
    'Дата',
    'Документ',
    'Операции',
    'Счет_дебет',
    'Сумма_дебет',
    'Счет_кредит',
    'Сумма_кредит',
    'Текущее_сальдо',
    'Сальдо'
]

df.head()
# Out:
#        Дата                                           Документ  \
# 0  03.01.24  Акт вып. работ (реализ) с табл. частью 0000000...
# 1  04.01.24                                Накладная ШЖ1827906
# 2  04.01.24                                Накладная ЭЕ0138064
# 3  04.01.24                                Накладная ШЖ1827907
# 4  04.01.24                                Накладная ШЖ1827908
#
#                                             Операции Счет_дебет Сумма_дебет  \
# 0  Акт вып.работ (реализ), табл, покупатель: ИСТ ...       62.1
# 1  Продажа (счет 90)/ Академическая книга Учтена ...       62.1
# 2  Продажа (счет 90)/ Авангард-торг Учтена выручк...       62.1
# 3  Продажа (счет 90)/ Кинг тут ООО Учтена выручка...       62.1
# 4  Продажа (счет 90)/ Апулья ООО Учтена выручка\n...       62.1
#
#   Счет_кредит Сумма_кредит Текущее_сальдо Сальдо
# 0       90.01        90,90
# 1       90.01     1 422,00
# 2       90.01        38,40
# 3       90.01     1 426,32
# ...

# %%
#для анализа нужна колонка Сумма_кредит. Смотрим тип колонки
df['Сумма_кредит'].head()
# Out:
# 0       90,90
# 1    1 422,00
# 2       38,40
# 3    1 426,32
# 4      201,26
# Name: Сумма_кредит, dtype: str

# %%
#переводим str в float64
cols = ['Сумма_дебет', 'Сумма_кредит', 'Текущее_сальдо', 'Сальдо']
for col in cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(' ', '', regex=False)
        .str.replace(',', '.', regex=False)
    )

df[cols] = df[cols].apply(
    pd.to_numeric,
    errors='coerce'
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Дата            1512 non-null   str
#  1   Документ        1510 non-null   str
#  2   Операции        1510 non-null   str
#  3   Счет_дебет      1510 non-null   str
#  4   Сумма_дебет     0 non-null      float64
#  5   Счет_кредит     1510 non-null   str
#  6   Сумма_кредит    1511 non-null   float64
#  7   Текущее_сальдо  0 non-null      float64
#  8   Сальдо          0 non-null      float64
# dtypes: float64(4), str(5)
# memory usage: 106.5 KB

# %%
#теперь можем посчитать все статистические показатели
df['Сумма_кредит'].describe()
# Out:
# count    1.511000e+03
# mean     2.486226e+03
# std      4.834913e+04
# min     -4.320000e+02
# 25%      1.622400e+02
# 50%      5.670000e+02
# 75%      1.352400e+03
# max      1.878906e+06
# Name: Сумма_кредит, dtype: float64

# %%
#выводим медиану
df['Сумма_кредит'].median()
# Out:
# np.float64(567.0)

# %%
#зная то, что при выгрузке ОСВ с 1с бухгалтерии, есть итогая строка, которая будет выбросом, обрезаем ее
df.tail(5)
# Out:
#                     Дата             Документ  \
# 1508            30.12.24  Накладная ЭЕ0138444
# 1509            30.12.24  Накладная УХ0227774
# 1510   Обороты за период                  NaN
# 1511  Сальдо на 31.12.24                  NaN
# 1512                 NaN                  NaN
#
#                                                Операции Счет_дебет  \
# 1508  Продажа (счет 90)/ РОЯЛОАК Учтена выручка\nРОЯ...       62.1
# 1509  Продажа (счет 90)/ Ажур Групп Учтена выручка\n...       62.1
# 1510                                                NaN        NaN
# 1511                                                NaN        NaN
# 1512                                                NaN        NaN
#
#       Сумма_дебет Счет_кредит  Сумма_кредит  Текущее_сальдо  Сальдо
# 1508          NaN       90.01        104.02             NaN     NaN
# 1509          NaN       90.01       7450.32             NaN     NaN
# 1510          NaN         NaN    1878905.91             NaN     NaN
# ...

# %%
#обрезаем
df = df.iloc[:-3]
df.tail(5)
# Out:
#           Дата             Документ  \
# 1505  30.12.24  Накладная УХ0227771
# 1506  30.12.24  Накладная УХ0227772
# 1507  30.12.24  Накладная ЭЕ0138443
# 1508  30.12.24  Накладная ЭЕ0138444
# 1509  30.12.24  Накладная УХ0227774
#
#                                                Операции Счет_дебет  \
# 1505  Продажа (счет 90)/ Представительство ТАСК Учте...       62.1
# 1506  Продажа (счет 90)/ Лаймарис ООО Учтена выручка...       62.1
# 1507  Продажа (счет 90)/ Корс Сити ООО Учтена выручк...       62.1
# 1508  Продажа (счет 90)/ РОЯЛОАК Учтена выручка\nРОЯ...       62.1
# 1509  Продажа (счет 90)/ Ажур Групп Учтена выручка\n...       62.1
#
#       Сумма_дебет Счет_кредит  Сумма_кредит  Текущее_сальдо  Сальдо
# 1505          NaN       90.01        367.20             NaN     NaN
# 1506          NaN       90.01        567.00             NaN     NaN
# 1507          NaN       90.01        356.72             NaN     NaN
# ...

# %%
#заново считаем показатели, они будут отличаться
df['Сумма_кредит'].describe()
# Out:
# count     1510.000000
# mean      1243.564192
# std       2083.744931
# min       -432.000000
# 25%        162.240000
# 50%        567.000000
# 75%       1348.650000
# max      26697.240000
# Name: Сумма_кредит, dtype: float64
